# %% [markdown]
# # Headers

# %%
import pandas as pd


import os
import dotenv
# Specify the path to your .env file
env_file_path = '/home/azureuser/cloudfiles/code/Users/vlavanga/.env' 

# Reload the variables and override existing ones
dotenv.load_dotenv(env_file_path, override=True)
# Out:
# True

# %% [markdown]
# # Connec & Query Snowflake

# %% [markdown]
# ## Make Connection

# %%
password = os.getenv("SNOWFLAKE_PASSWORD")
user=os.getenv("SNOWFLAKE_USER")
account=os.getenv("SNOWFLAKE_ACCOUNT")
warehouse=os.getenv("SNOWFLAKE_WAREHOUSE")
database=os.getenv("SNOWFLAKE_DATABASE")
schema='PUBLIC'

# %% [markdown]
# ## Query Data

# %%
import snowflake.connector

# %%
conn = snowflake.connector.connect(
    user=user,
    password=password,
    account=account,
    warehouse=warehouse,
    database=database,
    schema=schema
)

# %%
snowflake_query_base = pd.read_sql(
    '''
WITH deduped AS (SELECT DISTINCT * 
FROM NECCDMDEV.FACTS.FACT_PURCHASE_ORDER_ANALYSIS)
SELECT 
    po.PO_MATERIAL_KEY,
    po.PURCHASE_ORDER_DOCUMENT,
    po.PO_CREATED_DATE,
    po.SALES_ORG,
    dm.FABRIC_CONTENT_CODE_TEXT,
    dm.TEAM,
    dm.SILHOUETTE,
    dm.SPORT,
    dm.DIVISION_NAME,
    dm.EAN_UPC,
    dm.MARKET_SEGMENT,
    dm.GENDER,
    ds.SEASON_CONSOLIDATION,
    po.ORDERED_QUANTITY
FROM 
    deduped AS po
JOIN 
    NECCDMDEV.DIMENSIONS.DIM_MATERIAL AS dm
    ON po.PO_MATERIAL_KEY = dm.MATERIAL_KEY
JOIN 
    NECCDMDEV.DIMENSIONS.DIM_SEASON_COLLECTION AS ds
    ON po.SEASON_COLLECTION_KEY = ds.SEASON_COLLECTION_KEY;
''', 
conn)
# Out:
# /tmp/ipykernel_5552/1052042120.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   snowflake_query_base = pd.read_sql(

# %%
snowflake_query_v4 = pd.read_sql(
    '''
    SELECT *
FROM 
    NECCDMDEV.FACTS.FACT_PURCHASE_ORDER_ANALYSIS AS po
JOIN 
    NECCDMDEV.DIMENSIONS.DIM_MATERIAL AS dm
    ON po.PO_MATERIAL_KEY = dm.MATERIAL_KEY
JOIN 
    NECCDMDEV.DIMENSIONS.DIM_SEASON_COLLECTION AS ds
    ON po.SEASON_COLLECTION_KEY = ds.SEASON_COLLECTION_KEY;
''', 
conn)

# %%
snowflake_query_v4 = pd.read_sql(
    '''
    WITH deduped_po AS (
        SELECT DISTINCT *
        FROM NECCDMDEV.FACTS.FACT_PURCHASE_ORDER_ANALYSIS
    )
    SELECT 
    po.PO_MATERIAL_KEY,
    po.PURCHASE_ORDER_DOCUMENT,
    po.PO_CREATED_DATE,
    po.SALES_ORG,
    dm.FABRIC_CONTENT_CODE_TEXT,
    dm.TEAM,
    dm.SILHOUETTE,
    dm.SPORT,
    dm.DIVISION_NAME,
    dm.EAN_UPC,
    ds.SEASON_CONSOLIDATION,
    po.ORDERED_QUANTITY
FROM 
    deduped_po AS po
JOIN 
    NECCDMDEV.DIMENSIONS.DIM_MATERIAL AS dm
    ON po.PO_MATERIAL_KEY = dm.MATERIAL_KEY
JOIN 
    NECCDMDEV.DIMENSIONS.DIM_SEASON_COLLECTION AS ds
    ON po.SEASON_COLLECTION_KEY = ds.SEASON_COLLECTION_KEY;
''', 
conn)
# Out:
# /tmp/ipykernel_4656/597121876.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   snowflake_query_v4 = pd.read_sql(

# %% [markdown]
# MK,POA
# 0, 1, 5950, Stock
# 0, 2, 5950, Stock
# 1, 3, 5950, Stock
# 2, 4, 5950, Stock

# %%
len(snowflake_query_base)
# Out:
# 7822278

# %%
snowflake_query_base.to_csv('/home/azureuser/cloudfiles/code/Users/vlavanga/data/raw/snowflake_query_base.csv',index=False)

# %% [markdown]
# # Data Processing and CLeaning v4

# %%
snowflake_query_base = pd.read_csv('/home/azureuser/cloudfiles/code/Users/vlavanga/data/raw/snowflake_query_v5.2.csv')

# %%
snowflake_query_base.head()
# Out:
#                                      PO_MATERIAL_KEY  PURCHASE_ORDER_DOCUMENT  \
# 0  2d56d27d39a07fe26ea123a104d683150f2f17cf6ef856...               4500361594
# 1  2f5bafde67cef084dfe98f65542ad042a3931bf0f499dd...               4500510765
# 2  2253ef539c3fd88fcf8e0f35005dfc8890654cb1a2f5d6...               4500356699
# 3  09487d883519be50d6a9b4197c0378ff41f538dc99e159...               4500168656
# 4  9f7d5315c570a2857f94fa68ae78019079206b6cd47fe8...               4500054321
#
#    PO_CREATED_DATE  SALES_ORG FABRIC_CONTENT_CODE_TEXT                   TEAM  \
# 0         20220225       2000      100% Polyester Knit          BROOKLYN NETS
# 1         20251007       1700   Manmade fibers - Woven       NEW YORK YANKEES
# 2         20211221       1000          100% wool woven         ATLANTA BRAVES
# 3         20160823       1000          100% wool woven       NEW YORK YANKEES
# 4         20120221       1400         Polyester / Wool  PHILADELPHIA PHILLIES
#
#                SILHOUETTE       SPORT DIVISION_NAME       EAN_UPC  \
# 0  T-SHIRT - SHORT SLEEVE  BASKETBALL       Apparel  196499534314
# 1             5950 AFRAME    BASEBALL      Headwear  199420201507
# 2                    5950    BASEBALL      Headwear  195501604779
# 3                    5950    BASEBALL      Headwear  886611303347
# 4                    5950    BASEBALL      Headwear
#
#   SEASON_CONSOLIDATION  ORDERED_QUANTITY
# 0              Program               6.0
# 1              Program             216.0
# 2               Custom            2984.0
# 3               Custom             234.0
# 4               Custom             149.0

# %%
print(snowflake_query_base.shape)
# total sum of ORDERED_QUANTITY (handles non-numeric values)
total_order_qty = pd.to_numeric(snowflake_query_base['ORDERED_QUANTITY'], errors='coerce').sum()
total_order_qty
# Out:
# (7796850, 14)
# 1622352842.0

# %%
print(len(snowflake_query_base))
snowflake_query_base_dedup = snowflake_query_base.drop_duplicates()
print(len(snowflake_query_base_dedup))
# Out:
# 7796850
# 3375927

# %%
# total sum of ORDERED_QUANTITY (handles non-numeric values)
total_order_qty_dedup = pd.to_numeric(snowflake_query_base_dedup['ORDERED_QUANTITY'], errors='coerce').sum()
total_order_qty_dedup
# Out:
# 572831156.0

# %% [markdown]
# ## [Silhouette[5950,970] -> Regions [United States] -> Fabric Type [Woven] -> Division[Headwear] -> Season_Consolidation[Stock,Custom,Program]] -> [Sport,Team]
#
# ## 5950 -> United States -> Woven -> Headwear -> Stock

# %%
print(len(snowflake_query_base))
snowflake_query_base = snowflake_query_base[~snowflake_query_base['PURCHASE_ORDER_DOCUMENT'].astype(str).str.startswith('6')]
print(len(snowflake_query_base))
# Out:
# 7796157
# 7796149

# %%
# Drop Silhouette column, EAN_UPC, Market Segment, Product Hierarchy, Material Group,
snowflake_query_base = snowflake_query_base.drop(columns=['PO_MATERIAL_KEY','PURCHASE_ORDER_DOCUMENT', 'EAN_UPC'])

# %%
snowflake_query_base['SALES_ORG'].unique()
# Out:
# array(['2000', '1000', '5000', '1200', '3200', '3100', '3000', '1700',
#        '3500', '4000', '1400', '1500', '3300', '4100', '1300', '2100',
#        '4147', '3247', '2047', '4047', '2200'], dtype=object)

# %%
#snowflake_query_base['SALES_ORG'] = snowflake_query_base['SALES_ORG'].fillna(0)
#snowflake_query_base['SALES_ORG'] = snowflake_query_base['SALES_ORG'].astype(int)   

snowflake_query_base['ORDERED_QUANTITY'] = snowflake_query_base['ORDERED_QUANTITY'].astype(int)

# %%
fabric_text = snowflake_query_base['FABRIC_CONTENT_CODE_TEXT'].unique()

wovens = []
knits = []
poly = []
other = []
error_values = []

for word in fabric_text:
    try:
        val = str(word).lower()
        if "woven" in val:
            wovens.append(word)
        elif "knit" in val:
            knits.append(word)
        elif "polyester" in val or "poly" in val:
            poly.append(word)
        else:
            other.append(word)
    except:
        error_values.append(word)

# %%
def classify_fabric(value):
    try:
        val = str(value).lower()
        if value in wovens:
            return "Wovens"
        elif value in knits:
            return "Knits"
        elif value in val or "poly" in poly:
            return "Polyester"
        else:
            return "Other"
    except:
        return "Other"


insert_index = snowflake_query_base.columns.get_loc('FABRIC_CONTENT_CODE_TEXT') + 1
snowflake_query_base.insert(insert_index, 'FABRIC_TYPE', snowflake_query_base['FABRIC_CONTENT_CODE_TEXT'].apply(classify_fabric))

# %%
snowflake_query_base.head()
# Out:
#    PO_CREATED_DATE  SALES_ORG FABRIC_CONTENT_CODE_TEXT FABRIC_TYPE  \
# 0         20220225       2000      100% Polyester Knit       Knits
# 1         20251007       1700   Manmade fibers - Woven      Wovens
# 2         20211221       1000          100% wool woven      Wovens
# 3         20160823       1000          100% wool woven      Wovens
# 4         20120221       1400         Polyester / Wool       Other
#
#                     TEAM              SILHOUETTE       SPORT DIVISION_NAME  \
# 0          BROOKLYN NETS  T-SHIRT - SHORT SLEEVE  BASKETBALL       Apparel
# 1       NEW YORK YANKEES             5950 AFRAME    BASEBALL      Headwear
# 2         ATLANTA BRAVES                    5950    BASEBALL      Headwear
# 3       NEW YORK YANKEES                    5950    BASEBALL      Headwear
# 4  PHILADELPHIA PHILLIES                    5950    BASEBALL      Headwear
#
#   SEASON_CONSOLIDATION  ORDERED_QUANTITY
# 0              Program                 6
# 1              Program               216
# 2               Custom              2984
# 3               Custom               234
# 4               Custom               149

# %%
df_sales_org_new = pd.read_csv('/home/azureuser/cloudfiles/code/Users/vlavanga/data/raw/sales_org_info.csv')
df_sales_org_old = pd.read_csv('/home/azureuser/cloudfiles/code/Users/vlavanga/data/raw/sales_org_mapping.csv')

# %%
def classify_sales_org_name(value):
    try:
        if value in df_sales_org_new['SALES_ORGANIZATION'].values:
            return df_sales_org_new[df_sales_org_new['SALES_ORGANIZATION'] == value]['ENGLISH_NAME'].values[0]
        else:
            return "Other"
    except:
        return "Other"
    
def classify_sales_country(value):
    try:
        if value in df_sales_org_new['SALES_ORGANIZATION'].values:
            return df_sales_org_new[df_sales_org_new['SALES_ORGANIZATION'] == value]['COUNTRY'].values[0]
        else:
            return "Other"
    except:
        return "Other"
    
def classify_sales_region(value):
    try:
        if value in df_sales_org_new['SALES_ORGANIZATION'].values:
            return df_sales_org_new[df_sales_org_new['SALES_ORGANIZATION'] == value]['REGION'].values[0]
        else:
            return "Other"
    except:
        return "Other"

# %%
insert_index = snowflake_query_base.columns.get_loc('SALES_ORG') + 1
snowflake_query_base.insert(insert_index, 'SALES_ORG_NAME', snowflake_query_base['SALES_ORG'].apply(classify_sales_org_name))
print('org name complete')

insert_index = snowflake_query_base.columns.get_loc('SALES_ORG') + 1
snowflake_query_base.insert(insert_index, 'COUNTRY', snowflake_query_base['SALES_ORG'].apply(classify_sales_country))
print('country complete')


insert_index = snowflake_query_base.columns.get_loc('SALES_ORG') + 1
snowflake_query_base.insert(insert_index, 'REGION', snowflake_query_base['SALES_ORG'].apply(classify_sales_region))
print('country region')
# Out:
# org name complete
# country complete
# country region

# %%
snowflake_query_base.head()
# Out:
#    PO_CREATED_DATE  SALES_ORG            REGION              COUNTRY  \
# 0         20220225       2000              EMEA  GB : United Kingdom
# 1         20251007       1700  Emerging Markets             US : USA
# 2         20211221       1000     North America             US : USA
# 3         20160823       1000     North America             US : USA
# 4         20120221       1400  Emerging Markets             US : USA
#
#   SALES_ORG_NAME FABRIC_CONTENT_CODE_TEXT FABRIC_TYPE                   TEAM  \
# 0           EMEA      100% Polyester Knit       Knits          BROOKLYN NETS
# 1  Latin America   Manmade fibers - Woven      Wovens       NEW YORK YANKEES
# 2  United States          100% wool woven      Wovens         ATLANTA BRAVES
# 3  United States          100% wool woven      Wovens       NEW YORK YANKEES
# 4  Latin America         Polyester / Wool       Other  PHILADELPHIA PHILLIES
#
#                SILHOUETTE       SPORT DIVISION_NAME SEASON_CONSOLIDATION  \
# 0  T-SHIRT - SHORT SLEEVE  BASKETBALL       Apparel              Program
# 1             5950 AFRAME    BASEBALL      Headwear              Program
# 2                    5950    BASEBALL      Headwear               Custom
# 3                    5950    BASEBALL      Headwear               Custom
# 4                    5950    BASEBALL      Headwear               Custom
#
#    ORDERED_QUANTITY
# 0                 6
# 1               216
# 2              2984
# 3               234
# 4               149

# %%
snowflake_query_base.to_csv('/home/azureuser/cloudfiles/code/Users/vlavanga/data/processed/snowflake_v5.2_pre_ts.csv', index=False)

# %%
df = pd.read_csv('/home/azureuser/cloudfiles/code/Users/vlavanga/data/processed/snowflake_v4_pre_ts.csv')

# %% [markdown]
# ## [Silhouette[5950,970] -> Regions [United States] -> Fabric Type [Woven] -> Division[Headwear] -> Season_Consolidation[Stock,Custom,Program]] -> [Sport,Team]
#
# ## 5950 -> United States -> Woven -> Headwear -> Stock

# %% [markdown]
# ## Big picture categories
# Region[North America] -> Sales_Org[United States, US Retail, Canada, 5th & Ocean] -> Silhouette[5950, Low Profile 5950, 970, 950, 3930, 940, 920]
#
# ## 2nd Category
# Region[North America] -> Sales_Org[United States, US Retail, Canada, 5th & Ocean, Mexico] -> Silhouette[5950, Low Profile 5950, 970, 950, 3930, 940, 920] -> Season Consolidation[Stock, Program, Custom]

# %% [markdown]
# # Upload and Store Data

# %%
snowflake_query_v4 = pd.read_csv("/home/azureuser/cloudfiles/code/Users/vlavanga/data/processed/snowflake_v4_pre_ts.csv")

# %% [markdown]
# # Data Processing v5.1

# %%
df = pd.read_csv('/home/azureuser/cloudfiles/code/Users/vlavanga/data/processed/snowflake_v5_pre_ts.csv')
df = df[~df['SALES_ORG_NAME'].isin(['47 Japan','47 New Zealand','47 UK','47 Australia'])]
df.head()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 df = pd.read_csv('/home/azureuser/cloudfiles/code/Users/vlavanga/data/processed/snowflake_v5_pre_ts.csv')
#       2 df = df[~df['SALES_ORG_NAME'].isin(['47 Japan','47 New Zealand','47 UK','47 Australia'])]
#       3 df.head()
#
# File /anaconda/envs/nec10/lib/python3.10/site-packages/pandas/util/_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File /anaconda/envs/nec10/lib/python3.10/site-packages/pandas/util/_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File /anaconda/envs/nec10/lib/python3.10/site-packages/pandas/io/parsers/readers.py:950, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     935 kwds_defaults = _refine_defaults_read(
#     936     dialect,
#     937     delimiter,
#    (...)
#     946     defaults={"delimiter": ","},
#     947 )
#     948 kwds.update(kwds_defaults)
# --> 950 return _read(filepath_or_buffer, kwds)
#
# File /anaconda/envs/nec10/lib/python3.10/site-packages/pandas/io/parsers/readers.py:611, in _read(filepath_or_buffer, kwds)
#     608     return parser
#     610 with parser:
# --> 611     return parser.read(nrows)
#
# File /anaconda/envs/nec10/lib/python3.10/site-packages/pandas/io/parsers/readers.py:1795, in TextFileReader.read(self, nrows)
#    1792     else:
#    1793         new_rows = len(index)
# -> 1795     df = DataFrame(col_dict, columns=columns, index=index)
#    1797     self._currow += new_rows
#    1799 if self.squeeze and len(df.columns) == 1:
#
# File /anaconda/envs/nec10/lib/python3.10/site-packages/pandas/core/frame.py:664, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     658     mgr = self._init_mgr(
#     659         data, axes={"index": index, "columns": columns}, dtype=dtype, copy=copy
#     660     )
#     662 elif isinstance(data, dict):
#     663     # GH#38939 de facto copy defaults to False only in non-dict cases
# --> 664     mgr = dict_to_mgr(data, index, columns, dtype=dtype, copy=copy, typ=manager)
#     665 elif isinstance(data, ma.MaskedArray):
#     666     import numpy.ma.mrecords as mrecords
#
# File /anaconda/envs/nec10/lib/python3.10/site-packages/pandas/core/internals/construction.py:493, in dict_to_mgr(data, index, columns, dtype, typ, copy)
#     489     else:
#     490         # dtype check to exclude e.g. range objects, scalars
#     491         arrays = [x.copy() if hasattr(x, "dtype") else x for x in arrays]
# --> 493 return arrays_to_mgr(arrays, columns, index, dtype=dtype, typ=typ, consolidate=copy)
#
# File /anaconda/envs/nec10/lib/python3.10/site-packages/pandas/core/internals/construction.py:154, in arrays_to_mgr(arrays, columns, index, dtype, verify_integrity, typ, consolidate)
#     151 axes = [columns, index]
#     153 if typ == "block":
# --> 154     return create_block_manager_from_column_arrays(
#     155         arrays, axes, consolidate=consolidate
#     156     )
#     157 elif typ == "array":
#     158     return ArrayManager(arrays, [index, columns])
#
# File /anaconda/envs/nec10/lib/python3.10/site-packages/pandas/core/internals/managers.py:2199, in create_block_manager_from_column_arrays(arrays, axes, consolidate)
#    2182 def create_block_manager_from_column_arrays(
#    2183     arrays: list[ArrayLike],
#    2184     axes: list[Index],
#    (...)
#    2195     # These last three are sufficient to allow us to safely pass
#    2196     #  verify_integrity=False below.
#    2198     try:
# -> 2199         blocks = _form_blocks(arrays, consolidate)
#    2200         mgr = BlockManager(blocks, axes, verify_integrity=False)
#    2201     except ValueError as e:
#
# File /anaconda/envs/nec10/lib/python3.10/site-packages/pandas/core/internals/managers.py:2273, in _form_blocks(arrays, consolidate)
#    2270 if issubclass(dtype.type, (str, bytes)):
#    2271     dtype = np.dtype(object)
# -> 2273 values, placement = _stack_arrays(list(tup_block), dtype)
#    2274 if is_dtlike:
#    2275     values = ensure_wrapped_if_datetimelike(values)
#
# File /anaconda/envs/nec10/lib/python3.10/site-packages/pandas/core/internals/managers.py:2314, in _stack_arrays(tuples, dtype)
#    2312 stacked = np.empty(shape, dtype=dtype)
#    2313 for i, arr in enumerate(arrays):
# -> 2314     stacked[i] = arr
#    2316 return stacked, placement
#
# KeyboardInterrupt:

# %%
def edit_silhouette(value):    
    silhouette = ['5950','920','940','3930','950']
    if value in silhouette:
        return value
    else:
        return "Other"


insert_index = df.columns.get_loc('SILHOUETTE') + 1
df.insert(insert_index, 'SILHOUETTE_UPDATED', df['SILHOUETTE'].apply(edit_silhouette))

# %%
df['SILHOUETTE_UPDATE'].unique()
# Out:
# array(['Other', '940', '5950', '3930', '950', '920'], dtype=object)

# %%
df.head()
# Out:
#    PO_CREATED_DATE  SALES_ORG            REGION           COUNTRY  \
# 0         20231003       3200             Japan        JP : Japan
# 1         20231003       3200             Japan        JP : Japan
# 2         20231109       4100  Emerging Markets  NZ : New Zealand
# 3         20231103       1000     North America          US : USA
# 4         20231103       1000     North America          US : USA
#
#   SALES_ORG_NAME FABRIC_CONTENT_CODE_TEXT FABRIC_TYPE  \
# 0          Japan        100% Cotton woven      Wovens
# 1          Japan        100% Cotton woven      Wovens
# 2    New Zealand           Cotton - Woven      Wovens
# 3  United States   Manmade fibers - Woven      Wovens
# 4  United States   Manmade fibers - Woven      Wovens
#
#                       TEAM SILHOUETTE SILHOUETTE_UPDATE     SPORT  \
# 0           YOMIURI GIANTS     LP5950             Other  BASEBALL
# 1           YOMIURI GIANTS     LP5950             Other  BASEBALL
# 2        LAS VEGAS RAIDERS        940               940  FOOTBALL
# 3  RANCHO CUCAMONGA QUAKES       5950              5950  BASEBALL
# 4                RENO ACES       5950              5950  BASEBALL
#
#   DIVISION_NAME SEASON_CONSOLIDATION  ORDERED_QUANTITY
# 0      Headwear               Custom                72
# 1      Headwear               Custom                72
# 2      Headwear              Program                80
# 3      Headwear              Program                 1
# 4      Headwear              Program                 1

# %%
len(df)
# Out:
# 7741722

# %% [markdown]
# # Data Processing v5.2

# %%
import pandas as pd
df = pd.read_csv('/home/azureuser/cloudfiles/code/Users/vlavanga/data/processed/snowflake_v5.2_pre_ts.csv')
df = df[~df['SALES_ORG_NAME'].isin(['47 Japan','47 New Zealand','47 UK','47 Australia'])]
print("With PO value with startswith 6",len(df))
df.head()
# Out:
# With PO value with startswith 6 7795061
#    PO_CREATED_DATE  SALES_ORG            REGION              COUNTRY  \
# 0         20220225       2000              EMEA  GB : United Kingdom
# 1         20251007       1700  Emerging Markets             US : USA
# 2         20211221       1000     North America             US : USA
# 3         20160823       1000     North America             US : USA
# 4         20120221       1400  Emerging Markets             US : USA
#
#   SALES_ORG_NAME FABRIC_CONTENT_CODE_TEXT FABRIC_TYPE                   TEAM  \
# 0           EMEA      100% Polyester Knit       Knits          BROOKLYN NETS
# 1  Latin America   Manmade fibers - Woven      Wovens       NEW YORK YANKEES
# 2  United States          100% wool woven      Wovens         ATLANTA BRAVES
# 3  United States          100% wool woven      Wovens       NEW YORK YANKEES
# 4  Latin America         Polyester / Wool       Other  PHILADELPHIA PHILLIES
#
#                SILHOUETTE       SPORT DIVISION_NAME SEASON_CONSOLIDATION  \
# 0  T-SHIRT - SHORT SLEEVE  BASKETBALL       Apparel              Program
# 1             5950 AFRAME    BASEBALL      Headwear              Program
# 2                    5950    BASEBALL      Headwear               Custom
# 3                    5950    BASEBALL      Headwear               Custom
# 4                    5950    BASEBALL      Headwear               Custom
#
#    ORDERED_QUANTITY
# 0                 6
# 1               216
# 2              2984
# 3               234
# 4               149

# %%
def edit_silhouette(value):    
    silhouette = ['5950','920','940','3930','950']
    if value in silhouette:
        return value
    if value == 'NONE':
        return 'Unknown'
    else:
        return "Other"


insert_index = df.columns.get_loc('SILHOUETTE') + 1
df.insert(insert_index, 'SILHOUETTE_UPDATED', df['SILHOUETTE'].apply(edit_silhouette))

# %%
sports_info = {
    'COBRANDED BASEBALL': 'BASEBALL',
    'COBRANDED BASKETBALL': 'BASKETBALL',
    'COBRANDED RACING': 'RACING',
    'COBRANDED CORE': 'CORE',
    'COBRANDED NON LICENSED': 'NON LICENSED',
    'COBRANDED COLLEGE': 'COLLEGE',
    'COBRANDED FOOTBALL': 'FOOTBALL',
    'COBRANDED HOCKEY': 'HOCKEY',
    'COBRANDED SOCCER': 'SOCCER'
}

# %%
def edit_sport(value):
    try:
        if value in sports_info.keys():
            return sports_info[value]
        else:
            return value
    except:
        return value

# %%
insert_index = df.columns.get_loc('SPORT') + 1
df.insert(insert_index, 'SPORT_UPDATED', df['SPORT'].apply(edit_sport))
df.head()
# Out:
#    PO_CREATED_DATE  SALES_ORG            REGION              COUNTRY  \
# 0         20220225       2000              EMEA  GB : United Kingdom
# 1         20251007       1700  Emerging Markets             US : USA
# 2         20211221       1000     North America             US : USA
# 3         20160823       1000     North America             US : USA
# 4         20120221       1400  Emerging Markets             US : USA
#
#   SALES_ORG_NAME FABRIC_CONTENT_CODE_TEXT FABRIC_TYPE                   TEAM  \
# 0           EMEA      100% Polyester Knit       Knits          BROOKLYN NETS
# 1  Latin America   Manmade fibers - Woven      Wovens       NEW YORK YANKEES
# 2  United States          100% wool woven      Wovens         ATLANTA BRAVES
# 3  United States          100% wool woven      Wovens       NEW YORK YANKEES
# 4  Latin America         Polyester / Wool       Other  PHILADELPHIA PHILLIES
#
#                SILHOUETTE SILHOUETTE_UPDATED       SPORT SPORT_UPDATED  \
# 0  T-SHIRT - SHORT SLEEVE              Other  BASKETBALL    BASKETBALL
# 1             5950 AFRAME              Other    BASEBALL      BASEBALL
# 2                    5950               5950    BASEBALL      BASEBALL
# 3                    5950               5950    BASEBALL      BASEBALL
# 4                    5950               5950    BASEBALL      BASEBALL
#
#   DIVISION_NAME SEASON_CONSOLIDATION  ORDERED_QUANTITY
# 0       Apparel              Program                 6
# 1      Headwear              Program               216
# 2      Headwear               Custom              2984
# 3      Headwear               Custom               234
# 4      Headwear               Custom               149

# %%
df['SPORT_UPDATED'].unique()
# Out:
# array(['BASKETBALL', 'BASEBALL', 'FOOTBALL', 'RUGBY', 'NONE', 'COLLEGE',
#        'SOCCER', 'RACING', 'GOLF', 'ENTERTAINMENT', 'HOCKEY', 'WRESTLING',
#        'CORE', 'NON LICENSED', 'LACROSSE', 'CRICKET', 'TENNIS', 'BOXING',
#        nan, 'ANIMATED CHARACTER', 'E SPORT', 'CYCLING', 'WATER SPORTS',
#        'SNOWSPORTS', 'GAELIC FOOTBALL', 'VOLLEYBALL', 'SOFTBALL',
#        'HANDBALL'], dtype=object)

# %%
len(df)
# Out:
# 7795061

# %%
df = df.drop(columns=['SALES_ORG','FABRIC_CONTENT_CODE_TEXT','SILHOUETTE','SPORT'])

# %%
df.head()
# Out:
#    PO_CREATED_DATE         REGION              COUNTRY SALES_ORG_NAME  \
# 0         20230412           EMEA  GB : United Kingdom           EMEA
# 1         20200206  North America             US : USA  United States
# 2         20190215  North America             US : USA  United States
# 3         20150206  North America             US : USA    5th & Ocean
# 4         20210303  North America             US : USA  United States
#
#   FABRIC_TYPE                  TEAM SILHOUETTE_UPDATED SPORT_UPDATED  \
# 0       Other        HOUSTON ASTROS               5950      BASEBALL
# 1       Knits  ARIZONA DIAMONDBACKS               5950      BASEBALL
# 2       Knits   MICHIGAN WOLVERINES              Other       COLLEGE
# 3      Wovens         NEW YORK JETS              Other      FOOTBALL
# 4      Wovens      NEW YORK YANKEES               5950      BASEBALL
#
#   DIVISION_NAME             MARKET_SEGMENT GENDER SEASON_CONSOLIDATION  \
# 0      Headwear                  LIFESTYLE   MALE               Custom
# 1      Headwear                   ON FIELD   MALE              Program
# 2      Headwear                    FANGEAR   BOYS              Program
# 3       Apparel  WOMENS APPAREL - UPSTAIRS  YOUTH               Custom
# 4      Headwear                  LIFESTYLE   MALE               Custom
#
#    ORDERED_QUANTITY
# 0                72
# 1               288
# 2                48
# 3                53
# 4                64

# %%
len(df)
# Out:
# 7795754

# %%
df.to_csv('/home/azureuser/cloudfiles/code/Users/vlavanga/data/processed/snowflake_v5.2_pre_ts.csv', index=False)
